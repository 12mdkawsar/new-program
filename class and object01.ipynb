# %%
class phone:
  category = "Electronics"

  #object
apple = phone()
blueberry = phone()
motorola = phone()
print(apple.category)
print(apple.category)
print(motorola.category)
# Out:
# Electronics
# Electronics
# Electronics
